# %%
# Renomeia coluna a partir de um dicionário e rename

# %%
import pandas as pd
import numpy as np

# %%
import os
from pathlib import Path
p = Path(os.getcwd())
df = pd.read_csv(str(p.parent) + '\\bases_de_dados\\houses_to_rent.csv')

# %%
df.head(3)
# Out:
#    Unnamed: 0  city  area  rooms  bathroom  parking spaces floor animal  \
# 0           0     1   240      3         3               4     -  acept
# 1           1     0    64      2         1               1    10  acept
# 2           2     1   443      5         5               4     3  acept
#
#        furniture      hoa rent amount property tax fire insurance     total
# 0      furnished      R$0     R$8,000      R$1,000          R$121   R$9,121
# 1  not furnished    R$540       R$820        R$122           R$11   R$1,493
# 2      furnished  R$4,172     R$7,000      R$1,417           R$89  R$12,680

# %%
# Renomear colunas
colunas_anteriores = df.columns.to_list()
colunas_novas = ['indice', 'cidade', 'area_m2', 'quartos', 'banheiros', 'vagas_estacionamento', 
                 'andar', 'aceita_animais', 'mobiliado', 'valor_aluguel', 'taxas', 
                 'seguro_incendio', 'total']
colunas = dict((chave, valor) for chave, valor in zip(colunas_anteriores, colunas_novas))

df.rename(columns = colunas, inplace = True)

# %%
df.head(3)
# Out:
#    indice  cidade  area_m2  quartos  banheiros  vagas_estacionamento andar  \
# 0       0       1      240        3          3                     4     -
# 1       1       0       64        2          1                     1    10
# 2       2       1      443        5          5                     4     3
#
#   aceita_animais      mobiliado valor_aluguel    taxas seguro_incendio  total  \
# 0          acept      furnished           R$0  R$8,000         R$1,000  R$121
# 1          acept  not furnished         R$540    R$820           R$122   R$11
# 2          acept      furnished       R$4,172  R$7,000         R$1,417   R$89
#
#       total
# 0   R$9,121
# 1   R$1,493
# 2  R$12,680
