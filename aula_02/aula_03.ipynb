# %%
#Filtros booleanos para selecionar o DataFrame

# %%
import pandas as pd
import numpy as np

# %%
import os
from pathlib import Path
p = Path(os.getcwd())
df = pd.read_csv(str(p.parent) + '\\bases_de_dados\\houses_to_rent.csv')

# %%
df.head(3)
# Out:
#    Unnamed: 0  city  area  rooms  bathroom  parking spaces floor animal  \
# 0           0     1   240      3         3               4     -  acept
# 1           1     0    64      2         1               1    10  acept
# 2           2     1   443      5         5               4     3  acept
#
#        furniture      hoa rent amount property tax fire insurance     total
# 0      furnished      R$0     R$8,000      R$1,000          R$121   R$9,121
# 1  not furnished    R$540       R$820        R$122           R$11   R$1,493
# 2      furnished  R$4,172     R$7,000      R$1,417           R$89  R$12,680

# %%
#Filtrar locais com mais de 2 quartos E 3 banheiros
df[(df.rooms > 2) & (df.bathroom >3)].head(3)
# Out:
#     Unnamed: 0  city  area  rooms  bathroom  parking spaces floor animal  \
# 2            2     1   443      5         5               4     3  acept
# 13          13     1   375      4         5               5     1  acept
# 24          24     1   180      3         5               3     3  acept
#
#         furniture      hoa rent amount property tax fire insurance     total
# 2       furnished  R$4,172     R$7,000      R$1,417           R$89  R$12,680
# 13  not furnished  R$4,793    R$15,000      R$2,805          R$191  R$22,790
# 24  not furnished  R$2,900     R$8,100          R$0          R$103  R$11,100

# %%
#Filtrar locais que não estão no 2º andar
#df[~(df.floor == 2)].head(3)
df[(df.floor != 2)].head(3)
# Out:
#    Unnamed: 0  city  area  rooms  bathroom  parking spaces floor animal  \
# 0           0     1   240      3         3               4     -  acept
# 1           1     0    64      2         1               1    10  acept
# 2           2     1   443      5         5               4     3  acept
#
#        furniture      hoa rent amount property tax fire insurance     total
# 0      furnished      R$0     R$8,000      R$1,000          R$121   R$9,121
# 1  not furnished    R$540       R$820        R$122           R$11   R$1,493
# 2      furnished  R$4,172     R$7,000      R$1,417           R$89  R$12,680
