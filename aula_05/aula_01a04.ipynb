# %%
#Análise dos dados com describe, unique,

# %%
import pandas as pd
import numpy as np

# %%
import os 
from pathlib import Path
import os
from pathlib import Path
p = Path(os.getcwd())
df = pd.read_csv(str(p.parent) + '\\bases_de_dados\\houses_to_rent.csv')

# %%
df.head(3)
# Out:
#    Unnamed: 0  city  area  rooms  bathroom  parking spaces floor animal  \
# 0           0     1   240      3         3               4     -  acept
# 1           1     0    64      2         1               1    10  acept
# 2           2     1   443      5         5               4     3  acept
#
#        furniture      hoa rent amount property tax fire insurance     total
# 0      furnished      R$0     R$8,000      R$1,000          R$121   R$9,121
# 1  not furnished    R$540       R$820        R$122           R$11   R$1,493
# 2      furnished  R$4,172     R$7,000      R$1,417           R$89  R$12,680

# %%
df.dtypes
# Out:
# Unnamed: 0         int64
# city               int64
# area               int64
# rooms              int64
# bathroom           int64
# parking spaces     int64
# floor             object
# animal            object
# furniture         object
# hoa               object
# rent amount       object
# property tax      object
# fire insurance    object
# total             object
# dtype: object

# %%
#include='all' retorna as estatísticas das colunas numéricas e não numéricas
df.describe(include = 'all')
# Out:
#         Unnamed: 0         city          area        rooms     bathroom  \
# count   6080.00000  6080.000000   6080.000000  6080.000000  6080.000000
# unique         NaN          NaN           NaN          NaN          NaN
# top            NaN          NaN           NaN          NaN          NaN
# freq           NaN          NaN           NaN          NaN          NaN
# mean    3039.50000     0.863322    151.143914     2.492599     2.341612
# std     1755.28915     0.343535    375.559485     1.129665     1.438860
# min        0.00000     0.000000     10.000000     1.000000     1.000000
# 25%     1519.75000     1.000000     58.000000     2.000000     1.000000
# 50%     3039.50000     1.000000    100.000000     3.000000     2.000000
# 75%     4559.25000     1.000000    200.000000     3.000000     3.000000
# max     6079.00000     1.000000  24606.000000    10.000000    10.000000
#
#         parking spaces floor animal      furniture   hoa rent amount  \
# ...

# %%
#Verifica os valores únicos da coluna floor
df.floor.unique()
# Out:
# array(['-', '10', '3', '12', '2', '16', '6', '4', '1', '7', '13', '9',
#        '14', '5', '8', '15', '11', '19', '20', '24', '23', '17', '18',
#        '22', '27', '85', '28', '25', '29', '35', '21', '31', '99', '26',
#        '68', '32', '51'], dtype=object)

# %%
#Altera os dados da coluna floor onde há - para 0
df['floor'] = df['floor'].replace('-',0)
df.head(3)

# %%
df['floor'] = df['floor'].astype(np.int8)

# %%
df.dtypes
# Out:
# Unnamed: 0         int64
# city               int64
# area               int64
# rooms              int64
# bathroom           int64
# parking spaces     int64
# floor               int8
# animal            object
# furniture         object
# hoa               object
# rent amount       object
# property tax      object
# fire insurance    object
# total             object
# dtype: object
